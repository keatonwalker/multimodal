# %% [markdown]
# # Create some test data
# ### Join GTFS stop points to stop times

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, LineString
from scipy.spatial import cKDTree 
import os

import importlib
# local modules
import parse_functions
importlib.reload(parse_functions)

# %matplotlib inline

# %%
gtfs_dir = '../utah-transit-authority_20160331_1817'
routes = pd.read_csv(os.path.join(gtfs_dir, 'routes.txt'))
shapes = pd.read_csv(os.path.join(gtfs_dir, 'shapes.txt'))
trips = pd.read_csv(os.path.join(gtfs_dir, 'trips.txt'))
stops = pd.read_csv(os.path.join(gtfs_dir, 'stops.txt'))
stop_times = pd.read_csv(os.path.join(gtfs_dir, 'stop_times.txt'), dtype={'stop_id': object})
calendar = pd.read_csv(os.path.join(gtfs_dir, 'calendar.txt'))

# %%
# Speedy Spatial

def ckdnearest(gdA, gdB, bcol):
    """
    Get bcol for from every nearest point in gdA.
    See: https://gis.stackexchange.com/questions/222315/geopandas-find-nearest-point-in-other-dataframe
    """
    import time
    t = time.time()
    nA = np.array(list(zip(gdA.geometry.x, gdA.geometry.y)) )
    nB = np.array(list(zip(gdB.geometry.x, gdB.geometry.y)) )
    print('arrays', time.time() - t)

    t = time.time()
    btree = cKDTree(nB)
    print('tree', time.time() - t)

    t = time.time()
    dist, idx = btree.query(nA,k=1)
    print('query', time.time() - t)

    t = time.time()
    df = pd.DataFrame.from_dict({'distance': dist.astype(int),
                                 'aindex': gdA.index,
                                 'bcol_' + bcol : gdB.iloc[idx, gdB.columns.get_loc(bcol)].values })
    df.set_index('aindex', inplace=True)
    print('dataframe', time.time() - t)
    return df

#nearest_df = ckdnearest(subset_stops, subset_stops, 'stop_name')

# %%
stop_points = parse_functions.transform_xy_to_points(stops, 'stop_lon', 'stop_lat', 'stop_id')
stop_points.crs = {'init' :'epsg:4326'}
stop_points['geometry'] = stop_points['geometry'].to_crs(epsg=3857)
stop_points.head(3)
# Out:
#           stop_lat stop_code    stop_lon  stop_url  parent_station  \
# stop_id
# 11541    41.166905    629050 -111.962747       NaN             NaN
# 11546    41.206463    623264 -111.970663       NaN             NaN
# 11544    41.199655    623261 -111.970843       NaN             NaN
#
#                  stop_desc                 stop_name  location_type  zone_id  \
# stop_id
# 11541             E 5300 S            5300 S @ 711 E              0      NaN
# 11546    S WASHINGTON BLVD  WASHINGTON BLVD @ 3180 S              0      NaN
# 11544    S WASHINGTON BLVD  WASHINGTON BLVD @ 3500 S              0      NaN
#
#                                              geometry stop_id
# stop_id
# 11541    POINT (-12463635.98385612 5036991.371158207)   11541
# 11546    POINT (-12464517.18894524 5042842.771688678)   11546
# 11544    POINT (-12464537.22645358 5041835.483675041)   11544

# %%
shape_points = parse_functions.transform_xy_to_points(shapes, 'shape_pt_lon', 'shape_pt_lat', 'shape_id')
shape_points.crs = {'init' :'epsg:4326'}
shape_points['geometry'] = shape_points['geometry'].to_crs(epsg=3857)
shape_points.head(3)
# Out:
#           shape_pt_lat  shape_pt_lon  shape_pt_sequence  shape_dist_traveled  \
# shape_id
# 133799       40.390900   -111.577479                  1               0.0000
# 133799       40.390810   -111.577240                  2               0.0226
# 133799       40.390729   -111.577080                  3               0.0388
#
#                                               geometry  shape_id
# shape_id
# 133799    POINT (-12420748.14627717 4922910.465132287)    133799
# 133799    POINT (-12420721.54091888 4922897.310976486)    133799
# 133799    POINT (-12420703.72980035 4922885.472251293)    133799

# %%
nearest_df = ckdnearest(stop_points, shape_points, 'geometry')
# Out:
# arrays 8.315207481384277
# tree 0.2724027633666992
# query 0.02760004997253418
# dataframe 0.0040514469146728516

# %%
nearest_df.head()
# Out:
#                                        bcol_geometry  distance
# aindex
# 11541    POINT (-12463665.2608822 5037015.770540411)        38
# 11546   POINT (-12464532.43971548 5042783.142291525)        61
# 11544   POINT (-12464546.91124928 5041849.538823912)        17
# 11548   POINT (-12464515.74179186 5043703.517820037)        52
# 11549   POINT (-12464505.72303769 5044322.083014605)        53

# %%
stop_points.size
# Out:
# 68838

# %%
shape_points.size
# Out:
# 2152512

# %%
nearest_df.sort_values(by=['distance'], ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-a28cabf7306d> in <module>()
# ----> 1 nearest_df.sort_values(by=['distance'], ascending=False).head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'

# %%
nearest_df['distance'].sum()
# Out:
# 0

# %%
nearest_df.groupby('b_indx')['distance'].sum().sort_values(ascending=False)
# Out:
# b_indx
# 358743    0
# 131454    0
# 131507    0
# 131622    0
# 131769    0
# 131850    0
# 131852    0
# 131919    0
# 132020    0
# 132021    0
# 132513    0
# 132911    0
# 132938    0
# 133039    0
# 133264    0
# 133312    0
# 133555    0
# 131489    0
# 131427    0
# 133572    0
# 131389    0
# 130564    0
# 130686    0
# 130700    0
# 130738    0
# 130780    0
# 130783    0
# 130842    0
# 130890    0
# 130924    0
#          ..
# 248199    0
# 248205    0
# 248210    0
# 248246    0
# 248255    0
# 248256    0
# 248260    0
# 248303    0
# 248345    0
# 248364    0
# 248393    0
# 247634    0
# 247617    0
# 247591    0
# 247349    0
# 246465    0
# 246468    0
# 246489    0
# 246521    0
# 246636    0
# 247299    0
# 247381    0
# 247589    0
# 247398    0
# 247453    0
# 247463    0
# 247469    0
# 247536    0
# 247544    0
# 428       0
# Name: distance, Length: 4860, dtype: int32

# %% [markdown]
# # Make stop time points

# %%
stop_time_points = stop_times.join(stop_points, on='stop_id', lsuffix='_time', rsuffix='_stops')
len(stop_time_points.loc[stop_time_points['stop_id_stops'].isnull()])
# Out:
# 0

# %%
stop_time_points.head()
# Out:
#    trip_id arrival_time departure_time stop_id_time  stop_sequence  \
# 0  2729438     10:13:00       10:13:00        23259              1
# 1  2729438     10:13:30       10:13:30        22847              2
# 2  2729438     10:14:16       10:14:16        22831              3
# 3  2729438     10:14:33       10:14:33        23257              4
# 4  2729438     10:15:50       10:15:50        23255              5
#
#    stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  timepoint  \
# 0            NaN          NaN            NaN                  NaN        NaN
# 1            NaN          NaN            NaN                  NaN        NaN
# 2            NaN          NaN            NaN                  NaN        NaN
# 3            NaN          NaN            NaN                  NaN        NaN
# 4            NaN          NaN            NaN                  NaN        NaN
#
#        ...       stop_code    stop_lon  stop_url  parent_station  \
# 0      ...          198079 -112.004673       NaN             NaN
# 1      ...          101869 -112.005077       NaN             NaN
# 2      ...          101856 -112.005087       NaN             NaN
# 3      ...          198077 -112.005766       NaN             NaN
# 4      ...          198075 -112.013903       NaN             NaN
#
#            stop_desc                 stop_name location_type  zone_id  \
# 0  W OLD BINGHAM HWY  OLD BINGHAM HWY @ 4786 W             0      NaN
# 1           S 4800 W           4800 W @ 9253 S             0      NaN
# 2           S 4800 W           4800 W @ 9049 S             0      NaN
# 3           W 9000 S           9000 S @ 4820 W             0      NaN
# 4           W 9000 S           9000 S @ 5156 W             0      NaN
#
#                         geometry stop_id_stops
# 0  POINT (-112.004673 40.581717)         23259
# 1  POINT (-112.005077 40.583308)         22847
# 2  POINT (-112.005087 40.586969)         22831
# 3  POINT (-112.005766 40.588034)         23257
# 4  POINT (-112.013903 40.588043)         23255
#
# [5 rows x 21 columns]

# %%
stop_time_points = gpd.GeoDataFrame(stop_time_points, geometry='geometry')
stop_time_points.crs = {'init' :'epsg:4326'}

# %%
len(stop_time_points)
# Out:
# 1515685

# %%
# stop_time_points.to_file('data/stop_time_points.shp')

# %%
subset_size = 1000
subset_stops = stop_time_points.head(subset_size).copy()
# big_geo = subset_stops.geometry.unary_union

# %% [markdown]
# # Make stop to shape connections

# %%
len(stop_points)
# Out:
# 6258

# %%
len(shapes.groupby('shape_id')) * len(stop_points)
# Out:
# C:\Users\kwalker\AppData\Local\ESRI\conda\envs\geofun\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'shape_id' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
# 5438202

# %%
trip_stop_grp = stop_times.groupby(['stop_id', 'trip_id'])

# %%
len(trip_stop_grp)
# Out:
# 1514191

# %%
len(stop_times)
# Out:
# 1515685

# %%
stop_times.set_index('trip_id', inplace=True)

# %%
stop_times.index
# Out:
# Int64Index([2729438, 2729438, 2729438, 2729438, 2729438, 2729438, 2729438,
#             2729438, 2729438, 2729438,
#             ...
#             2729431, 2729431, 2729431, 2729431, 2729431, 2729431, 2729431,
#             2729431, 2729431, 2729431],
#            dtype='int64', name='trip_id', length=1515685)

# %%
trips.set_index('trip_id', inplace=True)

# %%
#trips.set_index('trip_id', inplace=True)
stop_shapes = stop_times.join(trips, lsuffix='_times', rsuffix='_trips')
stop_shapes.head()
# Out:
#         arrival_time departure_time stop_id  stop_sequence  stop_headsign  \
# trip_id
# 2507949     05:55:00       05:55:00   24384              1            NaN
# 2507949     05:59:16       05:59:16    5479              2            NaN
# 2507949     05:59:49       05:59:49   24221              3            NaN
# 2507949     06:00:36       06:00:36    5481              4            NaN
# 2507949     06:01:35       06:01:35   13105              5            NaN
#
#          pickup_type  drop_off_type  shape_dist_traveled  timepoint  block_id  \
# trip_id
# 2507949          NaN            NaN                  NaN        NaN  a_863938
# 2507949          NaN            NaN                  NaN        NaN  a_863938
# 2507949          NaN            NaN                  NaN        NaN  a_863938
# 2507949          NaN            NaN                  NaN        NaN  a_863938
# 2507949          NaN            NaN                  NaN        NaN  a_863938
#
#          route_id  direction_id              trip_headsign  shape_id  \
# trip_id
# 2507949     60966             0  University Medical Center    132426
# 2507949     60966             0  University Medical Center    132426
# 2507949     60966             0  University Medical Center    132426
# 2507949     60966             0  University Medical Center    132426
# 2507949     60966             0  University Medical Center    132426
#
#                service_id
# trip_id
# 2507949  4_merged_2787244
# 2507949  4_merged_2787244
# 2507949  4_merged_2787244
# 2507949  4_merged_2787244
# 2507949  4_merged_2787244

# %%
len(stop_shapes.groupby('shape_id'))
# Out:
# 736

# %%
stop_shapes.groupby(['stop_id', 'shape_id']).size()
# Out:
# stop_id  shape_id
# 1022     132426       38
#          132427       36
#          132430      134
#          132431      132
#          132444       74
#          132445       74
#          132469       24
#          132476        6
#          132477        6
#          132487        6
#          132488        6
#          132561       14
#          132562        2
#          132563       14
#          132588       11
#          132589       82
#          132590       11
#          132591       82
#          139173       19
#          139174       18
#          139177      115
#          139178      114
#          139191       81
#          139192       81
#          139216       12
#          139223        3
#          139224        3
#          139234        3
#          139235        3
#          139306        7
#                     ...
# 9612     132471       42
#          132476        6
#          132514        8
#          132517       12
#          132518       22
#          139207       23
#          139217       16
#          139218       67
#          139223        3
#          139260       11
#          139261        6
#          139264        4
# 9627     132747       76
#          139503       70
# 9662     132748       78
#          139504       75
# 9694     132759      162
#          139515      170
# 9705     132747       76
#          139503       70
# 9743     132748       78
#          139504       75
# 9883     132604        6
#          132605        3
#          132606      110
#          132607      104
#          139350      118
#          139351      153
#          139352        3
#          139353        6
# Length: 33390, dtype: int64

# %% [markdown]
# # Speedy Spatial

# %%
 def ckdnearest(gdA, gdB, bcol):
    """
    Get bcol for from every nearest point in gdA.
    See: https://gis.stackexchange.com/questions/222315/geopandas-find-nearest-point-in-other-dataframe
    """
    import time
    t = time.time()
    nA = np.array(list(zip(gdA.geometry.x, gdA.geometry.y)) )
    nB = np.array(list(zip(gdB.geometry.x, gdB.geometry.y)) )
    print('arrays', time.time() - t)
    
    t = time.time()
    btree = cKDTree(nB)
    print('tree', time.time() - t)
    
    t = time.time()
    dist, idx = btree.query(nA,k=2)
    print(dist)
#     print('query', time.time() - t)
    
#     t = time.time()
#     df = pd.DataFrame.from_dict({'distance': dist.astype(int),
#                              'bcol' : gdB.loc[idx, bcol].values })
#     print('dataframe', time.time() - t)
#     return df

nearest_df = ckdnearest(subset_stops, subset_stops, 'stop_name')
# nearest_df.head()
# Out:
# arrays 0.08613824844360352
# tree 0.0010581016540527344
# [[0.         0.        ]
#  [0.         0.        ]
#  [0.         0.        ]
#  ...
#  [0.         0.00278604]
#  [0.         0.00278604]
#  [0.         0.00238059]]

# %%
subset_stops.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
stop_time_points.head(100)
# Out:
#     trip_id arrival_time departure_time stop_id_time  stop_sequence  \
# 0   2729438     10:13:00       10:13:00        23259              1
# 1   2729438     10:13:30       10:13:30        22847              2
# 2   2729438     10:14:16       10:14:16        22831              3
# 3   2729438     10:14:33       10:14:33        23257              4
# 4   2729438     10:15:50       10:15:50        23255              5
# 5   2729438     10:17:00       10:17:00        23253              6
# 6   2729438     10:18:07       10:18:07        23312              7
# 7   2729438     10:19:00       10:19:00        23250              8
# 8   2729438     10:20:16       10:20:16        23248              9
# 9   2729438     10:20:51       10:20:51        23247             10
# 10      ...          198065 -112.012692       NaN             NaN
# 11      ...          198063 -112.012771       NaN             NaN
# 12      ...          101194 -112.006234       NaN             NaN
# 13      ...          101236 -112.006445       NaN             NaN
# 14      ...          101323 -112.007117       NaN             NaN
# 15      ...          151008 -112.007192       NaN             NaN
# 16      ...          151109 -112.007221       NaN             NaN
# 17      ...          101773 -112.006733       NaN             NaN
# 18      ...          151009 -112.005398       NaN             NaN
# 19      ...          101960 -112.005377       NaN             NaN
# 20      ...          151131 -112.005409       NaN             NaN
# 21      ...          101771 -112.005485       NaN             NaN
# 22      ...          198014 -112.004313       NaN             NaN
# 23      ...          101229 -112.007438       NaN             NaN
# 24      ...          101230 -112.009476       NaN             NaN
# 25      ...          101231 -112.007585       NaN             NaN
# 26      ...          101181 -112.005543       NaN             NaN
# 27      ...          134125 -112.005546       NaN             NaN
# 28      ...          134126 -112.005547       NaN             NaN
# 29      ...          134127 -112.005545       NaN             NaN
# ..      ...             ...         ...       ...             ...
# 70      ...          198063 -112.012771       NaN             NaN
# 71      ...          101194 -112.006234       NaN             NaN
# 72      ...          101236 -112.006445       NaN             NaN
# 73      ...          101323 -112.007117       NaN             NaN
# 74      ...          151008 -112.007192       NaN             NaN
# 75      ...          151109 -112.007221       NaN             NaN
# 76      ...          101773 -112.006733       NaN             NaN
# 77      ...          151009 -112.005398       NaN             NaN
# 78      ...          101960 -112.005377       NaN             NaN
# 79      ...          151131 -112.005409       NaN             NaN
# 80      ...          101771 -112.005485       NaN             NaN
# 81      ...          198014 -112.004313       NaN             NaN
# 82      ...          101229 -112.007438       NaN             NaN
# 83      ...          101230 -112.009476       NaN             NaN
# 84      ...          101231 -112.007585       NaN             NaN
# 85      ...          101181 -112.005543       NaN             NaN
# 86      ...          134125 -112.005546       NaN             NaN
# 87      ...          134126 -112.005547       NaN             NaN
# 88      ...          134127 -112.005545       NaN             NaN
# 89      ...          134128 -112.005561       NaN             NaN
# 90      ...          134129 -112.005566       NaN             NaN
# 91      ...          134130 -112.005601       NaN             NaN
# 92      ...          134131 -112.005597       NaN             NaN
# 93      ...          134132 -112.005602       NaN             NaN
# 94      ...          134133 -112.005602       NaN             NaN
# 95      ...          134135 -112.005601       NaN             NaN
# 96      ...          134136 -112.005604       NaN             NaN
# 97      ...          134137 -112.005611       NaN             NaN
# 98      ...          134138 -112.005617       NaN             NaN
# 99      ...          134139 -112.005622       NaN             NaN
#
#             stop_desc                 stop_name location_type  zone_id  \
# 0   W OLD BINGHAM HWY  OLD BINGHAM HWY @ 4786 W             0      NaN
# 1            S 4800 W           4800 W @ 9253 S             0      NaN
# 2            S 4800 W           4800 W @ 9049 S             0      NaN
# 3            W 9000 S           9000 S @ 4820 W             0      NaN
# 4            W 9000 S           9000 S @ 5156 W             0      NaN
# 5       S GRIZZLY WAY      GRIZZLY WAY @ 8731 S             0      NaN
# 6       S GRIZZLY WAY      GRIZZLY WAY @ 8461 S             0      NaN
# 7       S GRIZZLY WAY      GRIZZLY WAY @ 8271 S             0      NaN
# 8       S GRIZZLY WAY      GRIZZLY WAY @ 7981 S             0      NaN
# 9       S GRIZZLY WAY      GRIZZLY WAY @ 7761 S             0      NaN
# 10      S GRIZZLY WAY      GRIZZLY WAY @ 7381 S             0      NaN
# 11      S GRIZZLY WAY      GRIZZLY WAY @ 7061 S             0      NaN
# 12           W 7000 S           7000 S @ 4825 W             0      NaN
# 13        S COUGAR LN        COUGAR LN @ 6865 S             0      NaN
# 14           S 4800 W           4800 W @ 6725 S             0      NaN
# 15        S COUGAR LN        COUGAR LN @ 6587 S             0      NaN
# 16        S COUGAR LN        COUGAR LN @ 6425 S             0      NaN
# 17        S COUGAR LN        COUGAR LN @ 6307 S             0      NaN
# 18        S COUGAR LN        COUGAR LN @ 6221 S             0      NaN
# 19      S COUGAR LANE      COUGAR LANE @ 6007 S             0      NaN
# 20        S COUGAR LN           4800 W @ 5815 S             0      NaN
# 21        S COUGAR LN        COUGAR LN @ 5535 S             0      NaN
# 22    S NORTHWEST AVE    NORTHWEST AVE @ 5383 S             0      NaN
# 23      S PIEPER BLVD      PIEPER BLVD @ 5187 S             0      NaN
# 24           S 4980 W           4980 W @ 4983 S             0      NaN
# 25           S 4980 W           4980 W @ 4869 S             0      NaN
# 26           S 4800 W           4800 W @ 4667 S             0      NaN
# 27           S 4800 W           4800 W @ 4563 S             0      NaN
# 28           S 4800 W           4800 W @ 4505 S             0      NaN
# 29           S 4800 W           4800 W @ 4361 S             0      NaN
# ..                ...                       ...           ...      ...
# 70      S GRIZZLY WAY      GRIZZLY WAY @ 7061 S             0      NaN
# 71           W 7000 S           7000 S @ 4825 W             0      NaN
# 72        S COUGAR LN        COUGAR LN @ 6865 S             0      NaN
# 73           S 4800 W           4800 W @ 6725 S             0      NaN
# 74        S COUGAR LN        COUGAR LN @ 6587 S             0      NaN
# 75        S COUGAR LN        COUGAR LN @ 6425 S             0      NaN
# 76        S COUGAR LN        COUGAR LN @ 6307 S             0      NaN
# 77        S COUGAR LN        COUGAR LN @ 6221 S             0      NaN
# 78      S COUGAR LANE      COUGAR LANE @ 6007 S             0      NaN
# 79        S COUGAR LN           4800 W @ 5815 S             0      NaN
# 80        S COUGAR LN        COUGAR LN @ 5535 S             0      NaN
# 81    S NORTHWEST AVE    NORTHWEST AVE @ 5383 S             0      NaN
# 82      S PIEPER BLVD      PIEPER BLVD @ 5187 S             0      NaN
# 83           S 4980 W           4980 W @ 4983 S             0      NaN
# 84           S 4980 W           4980 W @ 4869 S             0      NaN
# 85           S 4800 W           4800 W @ 4667 S             0      NaN
# 86           S 4800 W           4800 W @ 4563 S             0      NaN
# 87           S 4800 W           4800 W @ 4505 S             0      NaN
# 88           S 4800 W           4800 W @ 4361 S             0      NaN
# 89           S 4800 W           4800 W @ 4291 S             0      NaN
# 90           S 4800 W           4800 W @ 4251 S             0      NaN
# 91           S 4800 W           4800 W @ 4177 S             0      NaN
# 92           S 4800 W           4800 W @ 4115 S             0      NaN
# 93           S 4800 W           4800 W @ 4051 S             0      NaN
# 94           S 4800 W           4800 W @ 3991 S             0      NaN
# 95           S 4800 W           4800 W @ 3845 S             0      NaN
# 96           S 4800 W           4800 W @ 3777 S             0      NaN
# 97           S 4800 W           4800 W @ 3701 S             0      NaN
# 98           S 4800 W           4800 W @ 3611 S             0      NaN
# 99           S 4800 W           4800 W @ 3565 S             0      NaN
#
#                                  geometry stop_id_stops
# 0           POINT (-112.004673 40.581717)         23259
# 1           POINT (-112.005077 40.583308)         22847
# 2           POINT (-112.005087 40.586969)         22831
# 3           POINT (-112.005766 40.588034)         23257
# 4           POINT (-112.013903 40.588043)         23255
# 5           POINT (-112.014617 40.592874)         23253
# 6            POINT (-112.01718 40.597704)         23312
# 7            POINT (-112.019933 40.60083)         23250
# 8           POINT (-112.013517 40.606621)         23248
# 9            POINT (-112.012559 40.61035)         23247
# 10          POINT (-112.012692 40.616746)         23245
# 11          POINT (-112.012771 40.622954)         23243
# 12          POINT (-112.006234 40.623981)         21441
# 13          POINT (-112.006445 40.626684)         21461
# 14          POINT (-112.007117 40.628804)         21594
# 15          POINT (-112.007192 40.631722)         16595
# 16          POINT (-112.007221 40.634565)         16597
# 17          POINT (-112.006733 40.636463)         22754
# 18          POINT (-112.005398 40.637934)         16599
# 19          POINT (-112.005377 40.642114)         22992
# 20          POINT (-112.005409 40.645425)         21146
# 21          POINT (-112.005485 40.650664)         22753
# 22          POINT (-112.004313 40.653335)         23065
# 23          POINT (-112.007438 40.657035)         21455
# 24  POINT (-112.009476 40.66099699999999)         21456
# 25          POINT (-112.007585 40.665431)         21457
# 26          POINT (-112.005543 40.668195)         21532
# 27          POINT (-112.005546 40.671011)         16616
# 28          POINT (-112.005547 40.673557)         16617
# 29          POINT (-112.005545 40.675647)         16618
# ..                                    ...           ...
# 70          POINT (-112.012771 40.622954)         23243
# 71          POINT (-112.006234 40.623981)         21441
# 72          POINT (-112.006445 40.626684)         21461
# 73          POINT (-112.007117 40.628804)         21594
# 74          POINT (-112.007192 40.631722)         16595
# 75          POINT (-112.007221 40.634565)         16597
# 76          POINT (-112.006733 40.636463)         22754
# 77          POINT (-112.005398 40.637934)         16599
# 78          POINT (-112.005377 40.642114)         22992
# 79          POINT (-112.005409 40.645425)         21146
# 80          POINT (-112.005485 40.650664)         22753
# 81          POINT (-112.004313 40.653335)         23065
# 82          POINT (-112.007438 40.657035)         21455
# 83  POINT (-112.009476 40.66099699999999)         21456
# 84          POINT (-112.007585 40.665431)         21457
# 85          POINT (-112.005543 40.668195)         21532
# 86          POINT (-112.005546 40.671011)         16616
# 87          POINT (-112.005547 40.673557)         16617
# 88          POINT (-112.005545 40.675647)         16618
# 89  POINT (-112.005561 40.67734799999999)         16619
# 90          POINT (-112.005566 40.678452)         16620
# 91          POINT (-112.005601 40.680101)         16621
# 92          POINT (-112.005597 40.681482)         16622
# 93          POINT (-112.005602 40.683078)         16892
# 94          POINT (-112.005602 40.684377)         16893
# 95          POINT (-112.005601 40.688207)         16895
# 96          POINT (-112.005604 40.689736)         16896
# 97          POINT (-112.005611 40.691548)         16897
# 98          POINT (-112.005617 40.693779)         16898
# 99          POINT (-112.005622 40.695318)         16899
#
# [100 rows x 21 columns]
